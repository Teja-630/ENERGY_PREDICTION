# %% [markdown]
# <a href="https://colab.research.google.com/github/Teja-630/ENERGY_PREDICTION/blob/main/week_1_Energy_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
df = pd.read_csv('solar_dataset.csv', parse_dates=['Date'])

print("Dataset Preview:\n", df.head())
X = df[['Irradiance', 'Temperature']]
y = df['Power_Output']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)


y_pred = model.predict(X_test)

print("\nMean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
result = df.loc[y_test.index].copy()
result['Predicted_Power'] = y_pred
print("\nPrediction Results:\n", result[['Date', 'Irradiance', 'Temperature', 'Power_Output', 'Predicted_Power']])
# Out:
# Dataset Preview:
#          Date  Irradiance  Temperature  Power_Output
# 0 2024-01-01         100           20           0.5
# 1 2024-01-02         200           22           1.2
# 2 2024-01-03         300           24           1.8
# 3 2024-01-04         400           25           2.6
# 4 2024-01-05         500           27           3.2
#
# Mean Absolute Error: 0.05220125786163421
# R² Score: 0.9983287296767711
#
# Prediction Results:
#          Date  Irradiance  Temperature  Power_Output  Predicted_Power
# 7 2024-01-08         800           32           4.9         4.993396
# 1 2024-01-02         200           22           1.2         1.257547
# 5 2024-01-06         600           29           3.8         3.805660
